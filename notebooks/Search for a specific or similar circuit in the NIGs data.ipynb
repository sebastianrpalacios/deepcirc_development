# %%
import re
from pathlib import Path

# ---------- 1.  Helpers ----------
def hex_to_truth_table(hex_code):
    """Return LSB-first 16-bit truth table for a 4-input Boolean function."""
    n = int(hex_code, 16)
    return [(n >> i) & 1 for i in range(16)]

HEX_PATTERN = re.compile(r'^(0x[0-9A-Fa-f]+)_')   # grabs the “0xABCD” at the front

def hex_from_filename(path):
    """Extract the leading 0x… word; return None if the pattern doesn’t match."""
    m = HEX_PATTERN.match(path.name)
    return m.group(1) if m else None

# ---------- 2.  Main sweep ----------
TARGET_HEX = "0x6197"
TARGET_TT  = hex_to_truth_table(TARGET_HEX)

directory_path = Path(
    "/home/gridsan/spalacios/DRL1/supercloud-testing/"
    "ABC-and-PPO-testing1/Verilog_files_for_all_4_input_1_output_truth_tables_as_NIGs/"
)

results = []

for f in directory_path.glob("*.pkl"):
    hex_word = hex_from_filename(f)
    if hex_word is None:
        continue                       # skip oddballs that don’t follow the naming rule
    tt       = hex_to_truth_table(hex_word)
    hamming  = sum(a ^ b for a, b in zip(tt, TARGET_TT))
    results.append((hamming, f))

# ---------- 3.  Report ----------
exact = [p for h, p in results if h == 0]
close = sorted((h, p) for h, p in results if 0 < h <= 2)

print(f"Target hex : {TARGET_HEX}")
print("Exact matches:")
for p in exact:
    print("  •", p.name)

print("\nVery similar (≤2 bits differ):")
for h, p in close:
    print(f"  • {p.name}  (Hamming distance {h})")
# Out:
# Target hex : 0x6197
# Exact matches:
#   • 0x6197_NIG_unoptimized.pkl
#
# Very similar (≤2 bits differ):
#   • 0x2197_NIG_unoptimized.pkl  (Hamming distance 1)
#   • 0x4197_NIG_unoptimized.pkl  (Hamming distance 1)
#   • 0x6097_NIG_unoptimized.pkl  (Hamming distance 1)
#   • 0x6117_NIG_unoptimized.pkl  (Hamming distance 1)
#   • 0x6187_NIG_unoptimized.pkl  (Hamming distance 1)
#   • 0x6193_NIG_unoptimized.pkl  (Hamming distance 1)
#   • 0x6195_NIG_unoptimized.pkl  (Hamming distance 1)
#   • 0x6196_NIG_unoptimized.pkl  (Hamming distance 1)
#   • 0x619F_NIG_unoptimized.pkl  (Hamming distance 1)
#   • 0x61B7_NIG_unoptimized.pkl  (Hamming distance 1)
#   • 0x61D7_NIG_unoptimized.pkl  (Hamming distance 1)
#   • 0x6397_NIG_unoptimized.pkl  (Hamming distance 1)
#   • 0x6597_NIG_unoptimized.pkl  (Hamming distance 1)
#   • 0x0197_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x2097_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x2117_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x2187_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x2193_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x2195_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x2196_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x219F_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x21B7_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x21D7_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x2397_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x2597_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x2997_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x3197_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x4097_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x4117_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x4187_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x4193_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x4195_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x4196_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x419F_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x41B7_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x41D7_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x4397_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x4597_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x4997_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x5197_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6017_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6087_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6093_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6095_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6096_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x609F_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x60B7_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x60D7_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6107_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6113_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6115_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6116_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x611F_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6137_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6157_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6183_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6185_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6186_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x618F_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6191_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6192_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6194_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x619B_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x619D_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x619E_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x61A7_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x61B3_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x61B5_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x61B6_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x61BF_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x61C7_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x61D3_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x61D5_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x61D6_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x61DF_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x61F7_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6297_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6317_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6387_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6393_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6395_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6396_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x639F_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x63B7_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x63D7_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6497_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6517_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6587_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6593_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6595_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x6596_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x659F_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x65B7_NIG_unoptimized.pkl  (Hamming distance 2)
#   • 0x65D7_NIG_unoptimized.pkl  (Hamming distance 2)
