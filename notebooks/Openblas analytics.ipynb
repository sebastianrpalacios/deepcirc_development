# %%
import sys, numpy as np, ctypes, os, platform, resource
print("python :", sys.executable)
print("numpy  :", np.__version__, "=>", np.__file__)
print("openblas:", ctypes.util.find_library("openblas") or "n/a")
print("start-method:", __import__("multiprocessing").get_start_method())
print("RLIMIT_NPROC:", resource.getrlimit(resource.RLIMIT_NPROC))
# Out:
# python : /state/partition1/llgrid/pkg/anaconda/anaconda3-2023a-pytorch/bin/python
# numpy  : 1.24.3 => /state/partition1/llgrid/pkg/anaconda/anaconda3-2023a-pytorch/lib/python3.9/site-packages/numpy/__init__.py
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       2 print("python :", sys.executable)
#       3 print("numpy  :", np.__version__, "=>", np.__file__)
# ----> 4 print("openblas:", ctypes.util.find_library("openblas") or "n/a")
#       5 print("start-method:", __import__("multiprocessing").get_start_method())
#       6 print("RLIMIT_NPROC:", resource.getrlimit(resource.RLIMIT_NPROC))
#
# AttributeError: module 'ctypes' has no attribute 'util'

# %%
import sys, numpy as np, os, resource, multiprocessing as mp, ctypes.util
print("python       :", sys.executable)
print("numpy        :", np.__version__, "→", np.__file__)
print("openblas lib :", ctypes.util.find_library('openblas') or "n/a")
print("start-method :", mp.get_start_method())
print("RLIMIT_NPROC :", resource.getrlimit(resource.RLIMIT_NPROC))
print("cpu cores    :", os.cpu_count())
# Out:
# python       : /usr/local/anaconda/anaconda3-2023a-pytorch/bin/python
# numpy        : 1.24.3 → /usr/local/anaconda/anaconda3-2023a-pytorch/lib/python3.9/site-packages/numpy/__init__.py
# openblas lib : /usr/local/anaconda/anaconda3-2023a-pytorch/lib/libopenblas.so.0
# start-method : fork
# RLIMIT_NPROC : (4096, 772185)
# cpu cores    : 64
