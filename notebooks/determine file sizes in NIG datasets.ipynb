# %%
import os

folder = "/home/gridsan/spalacios/DRL1/supercloud-testing/ABC-and-PPO-testing1/Verilog_files_for_all_4_input_1_output_truth_tables/"
count = sum(1 for e in os.scandir(folder) if e.is_file())
print(f"{folder} contains {count} regular files")

folder = "/home/gridsan/spalacios/DRL1/supercloud-testing/ABC-and-PPO-testing1/Verilog_files_for_all_4_input_1_output_truth_tables_as_SOPs/"
count = sum(1 for e in os.scandir(folder) if e.is_file())
print(f"{folder} contains {count} regular files")

folder = "/home/gridsan/spalacios/DRL1/supercloud-testing/ABC-and-PPO-testing1/Verilog_files_for_all_4_input_1_output_truth_tables_as_AIGs/"
count = sum(1 for e in os.scandir(folder) if e.is_file())
print(f"{folder} contains {count} regular files")

folder = "/home/gridsan/spalacios/DRL1/supercloud-testing/ABC-and-PPO-testing1/Verilog_files_for_all_4_input_1_output_truth_tables_as_NIGs/"
count = sum(1 for e in os.scandir(folder) if e.is_file())
print(f"{folder} contains {count} regular files")

folder = "/home/gridsan/spalacios/Designing complex biological circuits with deep neural networks/dgd/data/NIGs_4_inputs"
count = sum(1 for e in os.scandir(folder) if e.is_file())
print(f"{folder} contains {count} regular files")
# Out:
# /home/gridsan/spalacios/DRL1/supercloud-testing/ABC-and-PPO-testing1/Verilog_files_for_all_4_input_1_output_truth_tables/ contains 65539 regular files
# /home/gridsan/spalacios/DRL1/supercloud-testing/ABC-and-PPO-testing1/Verilog_files_for_all_4_input_1_output_truth_tables_as_SOPs/ contains 65536 regular files
# /home/gridsan/spalacios/DRL1/supercloud-testing/ABC-and-PPO-testing1/Verilog_files_for_all_4_input_1_output_truth_tables_as_AIGs/ contains 65536 regular files
# /home/gridsan/spalacios/DRL1/supercloud-testing/ABC-and-PPO-testing1/Verilog_files_for_all_4_input_1_output_truth_tables_as_NIGs/ contains 39387 regular files
# /home/gridsan/spalacios/Designing complex biological circuits with deep neural networks/dgd/data/NIGs_4_inputs contains 26153 regular files

# %%
import random

# Build the iterable once (lazy, doesn’t store all 39 382 ints at once)
numbers = range(26154, 65536)

# Pick 50 *unique* integers
sampled = random.sample(numbers, 50)

print(sampled)          # a list of 50 ints in random order
print(len(sampled))     # ➜ 50
# Out:
# [37804, 39925, 38647, 28822, 42930, 62884, 59706, 54608, 33323, 26695, 52098, 48291, 38289, 61419, 56314, 62695, 52182, 58999, 62527, 46916, 55936, 64633, 54391, 48873, 29046, 51046, 34062, 28458, 58885, 48150, 41690, 52887, 54041, 47277, 27037, 54500, 40842, 43360, 37258, 48950, 60657, 26634, 37196, 28908, 48625, 49736, 50354, 54054, 36707, 39191]
# 50

# %%
for n in sorted(sampled):
    print(f"0x{n:04X}")   # # => keep 0x, 06 => total width incl. 0x, pad with 0
# Out:
# 0x680A
# 0x6847
# 0x699D
# 0x6F2A
# 0x7096
# 0x70EC
# 0x7176
# 0x822B
# 0x850E
# 0x8F63
# 0x914C
# 0x918A
# 0x93AC
# 0x9591
# 0x96F7
# 0x9917
# 0x9BF5
# 0x9F8A
# 0xA2DA
# 0xA7B2
# 0xA960
# 0xB744
# 0xB8AD
# 0xBC16
# 0xBCA3
# 0xBDF1
# 0xBEE9
# 0xBF36
# 0xC248
# 0xC4B2
# 0xC766
# 0xCB82
# 0xCBD6
# 0xCE97
# 0xD319
# 0xD326
# 0xD477
# 0xD4E4
# 0xD550
# 0xDA80
# 0xDBFA
# 0xE605
# 0xE677
# 0xE93A
# 0xECF1
# 0xEFEB
# 0xF43F
# 0xF4E7
# 0xF5A4
# 0xFC79
